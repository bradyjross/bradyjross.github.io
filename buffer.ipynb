# %%
from arcgis.gis import GIS
from arcgis.features.use_proximity import create_buffers
gis = GIS("home")

# %%
# Item Added From Toolbar
# Title: Ponts_Buffer | Type: Feature Service | Owner: b.ross_NASA
item = gis.content.get("371eb005b827488da5ecfe613dbddbe9")
item
# Out:
# <Item title:"Ponts_Buffer" type:Feature Layer Collection owner:b.ross_NASA>

# %%
bufferitem = create_buffers(item,[1],units='Miles')
